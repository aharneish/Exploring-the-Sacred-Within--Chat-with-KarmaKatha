# %%
import pandas as pd

# %%
df=pd.read_csv("cleaned qa.csv")

# %%
df=df.iloc[:-200,]

# %%
df.to_csv("train.csv")

# %%
df_test=df.tail(200)

# %%
df.shape
# Out:
# (8389, 5)

# %%
df_test.shape
# Out:
# (200, 5)

# %%
df.head(10)
# Out:
#    Unnamed: 0                                           contexts  \
# 0           0                                                NaN
# 1           1   Brahmanda Purana, Book , Chapter , verse - - ...
# 2           2   Brahmanda Purana, Book , Chapter , verse  - T...
# 3           3   Brahmanda Purana, Book , Chapter , verses - -...
# 4           4   Brahmanda Purana, Book , Chapter , verse  - T...
# 5           5   Brahmanda Purana, Book , Chapter , verse - - ...
# 6           6   Brahmanda Purana, Book , Chapter , verse  - V...
# 7           7   Brahmanda Purana, Book , Chapter , verse  - T...
# 8           8   Brahmanda Purana, Book , Chapter , verse  - T...
# 9           9   Brahmanda Purana, Book , Chapter , verse  - R...
#
#                                             question  \
# 0    Describe the story of Lord Brahma's creation...
# 1    Name the cosmic egg mentioned in the Brahman...
# 2    Explain the concept of Yugas (eras) as depic...
# ...

# %%
df_test.head(10)
# Out:
#       Unnamed: 0                                           contexts  \
# 8189        8189   There are fourteen regions (lokas) in the uni...
# 8190        8190   Take the distance from bhuloka to the solar c...
# 8191        8191   Maharloka is above the world of Dhruva (Dhruv...
# 8192        8192   There are seven seas that surround the seven ...
# 8193        8193   In Satya Yuga, the best course to be pursued ...
# 8194        8194   Envy and jealousy were unknown in Satya Yuga,...
# 8195        8195   In Satya Yuga, water was always freely availa...
# 8196        8196   But gradually, anger and jealousy came to be ...
# 8197        8197                                                NaN
# 8198        8198   In Dvapara Yuga, hatred, anger, and jealousy ...
#
#                                                question  \
# 8189   What is the region of Dhruva, and which loka ...
# 8190   What is the significance of Maharloka in the ...
# ...

# %%
df_test.drop('Unnamed: 0',axis=1)
# Out:
#                                                contexts  \
# 8189   There are fourteen regions (lokas) in the uni...
# 8190   Take the distance from bhuloka to the solar c...
# 8191   Maharloka is above the world of Dhruva (Dhruv...
# 8192   There are seven seas that surround the seven ...
# 8193   In Satya Yuga, the best course to be pursued ...
# ...                                                 ...
# 8384                                                NaN
# 8385                                                NaN
# 8386                                                NaN
# 8387                                                NaN
# 8388                                                NaN
#
#                                                question  \
# 8189   What is the region of Dhruva, and which loka ...
# 8190   What is the significance of Maharloka in the ...
# 8191   How many seas surround the seven dvipas on ea...
# 8192   What is the primary god associated with each ...
# ...

# %%
df_test.to_csv("testqa.csv")

# %%
df.
